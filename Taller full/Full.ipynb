# %%
import pymongo
import pandas as pd

# %%
csv_file_path = r"C:\Users\capor\Downloads\customer_shopping_data_con_anio.csv"
df = pd.read_csv(csv_file_path)

# %%
df
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
# ...

# %%
client = pymongo.MongoClient('mongodb+srv://caporga:<password>@cluster0.df7t4ql.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')

# %%
url = 'mongodb+srv://caporga:Lx4eFNle06LPF6Iz@cluster0.df7t4ql.mongodb.net/'
db = client['Cluster0']
collection = db['Project 0']

# %%
data = df.to_dict(orient='records')
data
# Out:
# [{'invoice_no': 'I138884',
#   'customer_id': 'C241288',
#   'gender': 'Female',
#   'age': 28,
#   'category': 'Clothing',
#   'quantity': 5,
#   'price': 1500.4,
#   'payment_method': 'Credit Card',
#   'invoice_date': '2022-08-05',
#   'shopping_mall': 'Kanyon',
#   'total_spending': 7502.0,
#   'age_group': '18-35',
#   'year': 2022},
#  {'invoice_no': 'I317333',
#   'customer_id': 'C111565',
#   'gender': 'Male',
#   'age': 21,
#   'category': 'Shoes',
#   'quantity': 3,
#   'price': 1800.51,
#   'payment_method': 'Debit Card',
#   'invoice_date': '2021-12-12',
#   'shopping_mall': 'Forum Istanbul',
#   'total_spending': 5401.53,
#   'age_group': '18-35',
#   'year': 2021},
#  {'invoice_no': 'I127801',
#   'customer_id': 'C266599',
#   'gender': 'Male',
#   'age': 20,
#   'category': 'Clothing',
#   'quantity': 1,
#   'price': 300.08,
#   'payment_method': 'Cash',
#   'invoice_date': '2021-11-09',
#   'shopping_mall': 'Metrocity',
#   'total_spending': 300.08,
# ...

# %%
collection.insert_many(data)
# Out:
# ---------------------------------------------------------------------------
# OperationFailure                          Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 collection.insert_many(data)
#
# File c:\Users\capor\miniconda3\envs\API\lib\site-packages\pymongo\_csot.py:108, in apply.<locals>.csot_wrapper(self, *args, **kwargs)
#     106         with _TimeoutContext(timeout):
#     107             return func(self, *args, **kwargs)
# --> 108 return func(self, *args, **kwargs)
#
# File c:\Users\capor\miniconda3\envs\API\lib\site-packages\pymongo\collection.py:742, in Collection.insert_many(self, documents, ordered, bypass_document_validation, session, comment)
#     740 blk = _Bulk(self, ordered, bypass_document_validation, comment=comment)
#     741 blk.ops = list(gen())
# --> 742 blk.execute(write_concern, session, _Op.INSERT)
#     743 return InsertManyResult(inserted_ids, write_concern.acknowledged)
#
# ...

# %%
client = pymongo.MongoClient('mongodb+srv://caporga:Lx4eFNle06LPF6Iz@cluster0.df7t4ql.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')
db = client['Project2']
collection = db['sales']

data_dict = df.to_dict("records")

collection.insert_many(data_dict)

print("DataFrame insertado exitosamente en MongoDB Atlas")
