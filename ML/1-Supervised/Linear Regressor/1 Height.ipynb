# %% [markdown]
# ### Se pide, usando regresión lineal:
#
# Dibujar con una línea la relación que hay entre la altura y la edad de los alumnos de esta clase:
#
# - ¿Es una buena técnica para este tipo de problemas? ¿Por qué?
# - ¿Qué error se comete? Calcula los errores que está cometiendo tu modelo uno a uno (lo tienes que calcular tú con python). Aparte, usa el MSE y el RMSE. ¿Alguno es mejor para este problema?
# - Representa la matriz de correlación, ¿los datos están correlacionados?

# %%
lista_alumnos = [("Caranchoa", 24, 1.82), 
                 ("Leo Messi", 25, 1.71), 
                 ("El bicho", 35, 1.66), 
                 ("Paquirrin", 37, 1.63), 
                 ("John Cobra", 29, 1.90), 
                 ("El tomate", 27, 1.80), 
                 ("El chucky de cieza", 28, 1.70), 
                 ("Chiquito de la Calzada", 32, 1.60), 
                 ("El cuñao", 36, 1.74), 
                 ("Rafa Nadal", 45, 1.72), 
                 ("Pau Gasol", 41, 1.65), 
                 ("El hermano de Pau Gasol", 30, 1.65), 
                 ("Joselito", 40, 1.60), 
                 ("Maria Isabel", 39, 1.80), 
                 ("Melody", 23, 1.77), 
                 ("Las ketchup", 32, 1.75), 
                 ("Pumuki", 27, 1.70), 
                 ("Naranjito", 34, 1.80), 
                 ("Espinete", 27, 1.77), 
                 ("El Feli", 28, 1.70), 
                 ("Jose Luis", 35, 1.80)]

# %%
# import pandas as pd
import pandas as pd
import seaborn as sns

# %%
# Crea el siguiente DataFrame
df = pd.DataFrame(lista_alumnos)
df.rename(columns={0:"Nombre",1:"Edad",2:"Estatura"})
# Out:
#                      Nombre  Edad  Estatura
# 0                 Caranchoa    24      1.82
# 1                 Leo Messi    25      1.71
# 2                  El bicho    35      1.66
# 3                 Paquirrin    37      1.63
# 4                John Cobra    29      1.90
# 5                 El tomate    27      1.80
# 6        El chucky de cieza    28      1.70
# 7    Chiquito de la Calzada    32      1.60
# 8                  El cuñao    36      1.74
# 9                Rafa Nadal    45      1.72
# 10                Pau Gasol    41      1.65
# 11  El hermano de Pau Gasol    30      1.65
# 12                 Joselito    40      1.60
# 13             Maria Isabel    39      1.80
# 14                   Melody    23      1.77
# 15              Las ketchup    32      1.75
# 16                   Pumuki    27      1.70
# 17                Naranjito    34      1.80
# 18                 Espinete    27      1.77
# 19                  El Feli    28      1.70
# 20                Jose Luis    35      1.80

# %%
# Muestra la info
df.info
# Out:
# <bound method DataFrame.info of                           0   1     2
# 0                 Caranchoa  24  1.82
# 1                 Leo Messi  25  1.71
# 2                  El bicho  35  1.66
# 3                 Paquirrin  37  1.63
# 4                John Cobra  29  1.90
# 5                 El tomate  27  1.80
# 6        El chucky de cieza  28  1.70
# 7    Chiquito de la Calzada  32  1.60
# 8                  El cuñao  36  1.74
# 9                Rafa Nadal  45  1.72
# 10                Pau Gasol  41  1.65
# 11  El hermano de Pau Gasol  30  1.65
# 12                 Joselito  40  1.60
# 13             Maria Isabel  39  1.80
# 14                   Melody  23  1.77
# 15              Las ketchup  32  1.75
# 16                   Pumuki  27  1.70
# 17                Naranjito  34  1.80
# 18                 Espinete  27  1.77
# 19                  El Feli  28  1.70
# 20                Jose Luis  35  1.80>

# %%
# Muestra los estadísticos del df
df.describe()
df.rename(columns={0: "Nombre", 1: "Edad", 2: "Estatura"}, inplace=True)
df
# Out:
#                      Nombre  Edad  Estatura
# 0                 Caranchoa    24      1.82
# 1                 Leo Messi    25      1.71
# 2                  El bicho    35      1.66
# 3                 Paquirrin    37      1.63
# 4                John Cobra    29      1.90
# 5                 El tomate    27      1.80
# 6        El chucky de cieza    28      1.70
# 7    Chiquito de la Calzada    32      1.60
# 8                  El cuñao    36      1.74
# 9                Rafa Nadal    45      1.72
# 10                Pau Gasol    41      1.65
# 11  El hermano de Pau Gasol    30      1.65
# 12                 Joselito    40      1.60
# 13             Maria Isabel    39      1.80
# 14                   Melody    23      1.77
# 15              Las ketchup    32      1.75
# 16                   Pumuki    27      1.70
# 17                Naranjito    34      1.80
# 18                 Espinete    27      1.77
# 19                  El Feli    28      1.70
# 20                Jose Luis    35      1.80

# %%
# Genera un scatter plot con Edad y Altura
import matplotlib.pyplot as plt
plt.scatter(x=df.loc[:,"Edad"], y=df.loc[:,"Estatura"])
plt.xlabel("Edad", size=15)
plt.ylabel("Estatura", size=15)
# Out:
# Text(0, 0.5, 'Estatura')

# %%
# Genera un heatmap
#eliminamos caranchoa porque no es numérica
df = df.drop(columns='Nombre')  # Elimina la columna 'Nombre'
sns.heatmap(df.corr(), annot=True);

# %%
# Genera un distplot
sns.distplot(df['Estatura']);
# Out:
# C:\Users\Usuario\AppData\Local\Temp\ipykernel_19772\2523056631.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Estatura']);

# %%
X = df[["Edad"]]
X
# Out:
#     Edad
# 0     24
# 1     25
# 2     35
# 3     37
# 4     29
# 5     27
# 6     28
# 7     32
# 8     36
# 9     45
# 10    41
# 11    30
# 12    40
# 13    39
# 14    23
# 15    32
# 16    27
# 17    34
# 18    27
# 19    28
# 20    35

# %%
y = df[['Estatura']]
y
# Out:
#     Estatura
# 0       1.82
# 1       1.71
# 2       1.66
# 3       1.63
# 4       1.90
# 5       1.80
# 6       1.70
# 7       1.60
# 8       1.74
# 9       1.72
# 10      1.65
# 11      1.65
# 12      1.60
# 13      1.80
# 14      1.77
# 15      1.75
# 16      1.70
# 17      1.80
# 18      1.77
# 19      1.70
# 20      1.80

# %%
# from sklearn.model_selection import train_test_split

# Divide los datos en conjunto de entrenamiento y test
# Siendo el tamaño del conjunto test un 30% y la semilla sea 42
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.30, random_state = 42)

# %%
# Muestra el tamaño de X, X_train, y_train, X_test e y_test

print("Total features shape:", X.shape)
print("Train features shape:", X_train.shape)
print("Train target shape:", y_train.shape)
print("Test features shape:", X_test.shape)
print("Test target shape:", y_test.shape)
# Out:
# Total features shape: (21, 1)
# Train features shape: (14, 1)
# Train target shape: (14, 1)
# Test features shape: (7, 1)
# Test target shape: (7, 1)

# %%
# Instancia y entrena un regresor lineal
from sklearn.linear_model import LinearRegression
lm = LinearRegression()
lm.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# imprime el intercepto y el coeficiente
print(lm.intercept_)
print(lm.coef_)
# Out:
# [1.85209063]
# [[-0.00414006]]

# %% [markdown]
# (Altura) = 1.85 - 0.0041*(Edad)

# %%
# Realiza una predicción con el conjunto de test

predictions = lm.predict(X_test)
predictions
# Out:
# array([[1.75272915],
#        [1.71132853],
#        [1.71960865],
#        [1.74858908],
#        [1.7030484 ],
#        [1.74030896],
#        [1.72788877]])

# %%
# Crea un df con el conjunto de test
# df_test
df_test = df.loc[:,"Edad"]
df_test
# Out:
# 0     24
# 1     25
# 2     35
# 3     37
# 4     29
# 5     27
# 6     28
# 7     32
# 8     36
# 9     45
# 10    41
# 11    30
# 12    40
# 13    39
# 14    23
# 15    32
# 16    27
# 17    34
# 18    27
# 19    28
# 20    35
# Name: Edad, dtype: int64

# %%
# Añade una columna con la predicción

X_test["predict_height"] = df_test
X_test
# Out:
#     Edad  predict_height
# 0     24              24
# 17    34              34
# 15    32              32
# 1     25              25
# 8     36              36
# 5     27              27
# 11    30              30

# %%
# Añade una columna con la altura real

X_test["Estatura"] = df["Estatura"]
X_test
# Out:
#     Edad  predict_height  Estatura
# 0     24              24      1.82
# 17    34              34      1.80
# 15    32              32      1.75
# 1     25              25      1.71
# 8     36              36      1.74
# 5     27              27      1.80
# 11    30              30      1.65

# %%
import matplotlib.pyplot as plt

# Datos
edad = [24, 34, 32, 25, 36, 27, 30]
estatura_real = [1.82, 1.80, 1.75, 1.71, 1.74, 1.80, 1.65]
estatura_predicha = [1.752729, 1.711329, 1.719609, 1.748589, 1.703048, 1.740309, 1.727889]

# Crear el gráfico
plt.figure(figsize=(10, 6))
plt.plot(edad, estatura_real, marker='o', linestyle='none', color='b', label='Estatura Real')
plt.plot(edad, estatura_predicha, marker='o', linestyle='--', color='r', label='Estatura Predicha')

# Etiquetas y título
plt.xlabel('Edad')
plt.ylabel('Estatura')
plt.title('Comparación entre Estatura Real y Estatura Predicha')
plt.legend()

# Mostrar el gráfico
plt.grid(True)
plt.show()

# %%
# Crea un plot con los datos reales y la predicción

# %%
# Muestra el score del módelo
# Out:
# 0.0977354475123352

# %%
# Out:
#     Edad  predict_height  real_height
# 0     24        1.752729         1.82
# 17    34        1.711329         1.80
# 15    32        1.719609         1.75
# 1     25        1.748589         1.71
# 8     36        1.703048         1.74
# 5     27        1.740309         1.80
# 11    30        1.727889         1.65

# %%
# from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_absolute_percentage_error

# %%
# Muestra el Mean Absolute Error, el Mean Squared Error y el Root Mean Squared Error
# Out:
# MAE: 0.05706488156539665
# MSE: 0.0036851216240520687
# RMSE: 0.060705202611078306

# %%
# Muestra el Mean Absolute Percentage Error
# Out:
# MAPE: 0.03253724207144201

# %%
# Muestra cual sería la predicción para 85 años de edad
# Out:
# c:\Users\Rodrigo\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([1.50018538])

# %%
# Ahora vamos a calcular el MAE, MSE, RMSE y MAPE a mano

# %%
# Añade una columna con el error
# Out:
#     Edad  predict_height  real_height     error
# 0     24        1.752729         1.82  0.067271
# 17    34        1.711329         1.80  0.088671
# 15    32        1.719609         1.75  0.030391
# 1     25        1.748589         1.71  0.038589
# 8     36        1.703048         1.74  0.036952
# 5     27        1.740309         1.80  0.059691
# 11    30        1.727889         1.65  0.077889

# %%
# Muestra el error medio
# Out:
# 0.05706488156539665

# %%
# Añade una columna que contenga el error cuadrático
# Out:
#     Edad  predict_height  real_height     error  error_cuadratico
# 0     24        1.752729         1.82  0.067271          0.004525
# 17    34        1.711329         1.80  0.088671          0.007863
# 15    32        1.719609         1.75  0.030391          0.000924
# 1     25        1.748589         1.71  0.038589          0.001489
# 8     36        1.703048         1.74  0.036952          0.001365
# 5     27        1.740309         1.80  0.059691          0.003563
# 11    30        1.727889         1.65  0.077889          0.006067

# %%
# Muestra el error cuadrático medio
# Out:
# 0.0036851216240520687

# %%
# Muestra la raíz del error cuadrático medio
# Out:
# 0.060705202611078306

# %%
# Muestra el error absoluto medio porcentual
# Out:
# 0.032555352156298005
